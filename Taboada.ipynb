# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniloBucker/Analista-de-dados/blob/main/Projeto1_Taboada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Projeto: Gerador de Tabuada Interativo
# 📋 Descrição do Projeto
# Desenvolvimento de uma aplicação em Python para geração dinâmica de tabuadas, com foco em validação de dados e experiência do usuário.
#
# 🛠 Atividades Desenvolvidas
# 1. Análise de Requisitos e Planejamento
# Especificação dos requisitos funcionais: entrada do usuário, validação de intervalo (1-10), cálculo matemático
#
# Definição da arquitetura da solução utilizando programação estruturada
#
# Planejamento da lógica de programação com estruturas de repetição
#
# 2. Desenvolvimento do Algoritmo Principal
# python
# # Implementação da lógica de programação com validação de inputs
# def gerar_tabuada():
#     while True:
#         try:
#             numero = int(input("Digite um número inteiro de 1 a 10: "))
#             if 1 <= numero <= 10:
#                 print(f"\nTabuada do {numero}:")
#                 for i in range(1, 11):
#                     resultado = numero * i
#                     print(f"{numero} × {i} = {resultado}")
#                 break
#             else:
#                 print("❌ Erro: Digite um número entre 1 e 10!")
#         except ValueError:
#             print("❌ Erro: Por favor, digite um número inteiro válido!")
# 3. Implementação de Tratamento de Erros
# Validação de tipo de dados para entrada numérica
#
# Controle de intervalo (1-10) com mensagens de erro específicas
#
# Estrutura de repetição para nova tentativa em caso de erro
#
# 4. Otimização e Melhorias de UX
# Formatação de saída para melhor legibilidade dos dados
#
# Mensagens informativas para orientação do usuário
#
# Estrutura user-friendly com feedback imediato
#
# 5. Testes e Validação
# Teste de casos limite (1, 10, valores fora do range)
#
# Validação de entradas inválidas (strings, floats, negativos)
#
# Verificação da precisão dos cálculos matemáticos
#
# 💻 Habilidades Técnicas Aplicadas
# Programação Estruturada
# Estruturas de controle (if-else, for loop)
#
# Manipulação de inputs/outputs
#
# Validação e sanitização de dados
#
# Lógica Computacional
# Algoritmos matemáticos para operações sequenciais
#
# Controle de fluxo com tratamento de exceções
#
# Otimização de processos iterativos
#
# Gestão de Projeto
# Análise de requisitos do usuário
#
# Desenvolvimento incremental com feedback contínuo
#
# Documentação do código e funcionalidades
#
# 📊 Resultados Obtidos
# ✅ Aplicação funcional com 100% de precisão nos cálculos
#
# ✅ Interface intuitiva com tratamento robusto de erros
#
# ✅ Código escalável para futuras implementações (POO, interface gráfica)
#
# ✅ Base sólida para projetos mais complexos de automação e análise
#
# 🚀 Próximos Passos: Integração com interface gráfica (Tkinter), exportação de resultados para CSV, ou versão web com Flask para ampliar as aplicações práticas.

# %%
# Implementação da lógica de programação com validação de inputs
def gerar_tabuada():
    while True:
        try:
            numero = int(input("Digite um número inteiro de 1 a 10: "))
            if 1 <= numero <= 10:
                print(f"\nTabuada do {numero}:")
                for i in range(1, 11):
                    resultado = numero * i
                    print(f"{numero} × {i} = {resultado}")
                break
            else:
                print("❌ Erro: Digite um número entre 1 e 10!")
        except ValueError:
            print("❌ Erro: Por favor, digite um número inteiro válido!")

# %%
gerar_tabuada()
# Out:
# Digite um número inteiro de 1 a 10: 7
#
# Tabuada do 7:
# 7 × 1 = 7
# 7 × 2 = 14
# 7 × 3 = 21
# 7 × 4 = 28
# 7 × 5 = 35
# 7 × 6 = 42
# 7 × 7 = 49
# 7 × 8 = 56
# 7 × 9 = 63
# 7 × 10 = 70
